# %%
import boto3
from pathlib import Path

# ---- Config ----
bucket = "us-housing-regression-data"   # replace with your bucket name
region = "us-east-1"                 # your AWS region

# Set project root as parent of the notebooks folder
PROJECT_ROOT = Path.cwd().parent
print(PROJECT_ROOT)
local_data_dir = PROJECT_ROOT / "data" / "processed"
local_model_dir = PROJECT_ROOT / "models"

s3 = boto3.client("s3", region_name=region)

# ---- Helper function ----
def upload_file(local_path: Path, s3_key: str):
    if not local_path.exists():
        print(f"❌ File not found: {local_path}")
        return
    print(f"⬆️ Uploading {local_path} → s3://{bucket}/{s3_key}")
    s3.upload_file(str(local_path), bucket, s3_key)

# ---- Upload required datasets ----
upload_file(local_data_dir / "feature_engineered_holdout.csv", "processed/feature_engineered_holdout.csv")
upload_file(local_data_dir / "cleaning_holdout.csv", "processed/cleaning_holdout.csv")
upload_file(local_data_dir / "feature_engineered_train.csv", "processed/feature_engineered_train.csv")

# ---- Upload model ----
upload_file(local_model_dir / "xgb_best_model.pkl", "models/xgb_best_model.pkl")
# Out:
# /local/vol00/home/troy3/vscode_workspace/Regression_MLOps_End2End
# ⬆️ Uploading /local/vol00/home/troy3/vscode_workspace/Regression_MLOps_End2End/data/processed/feature_engineered_holdout.csv → s3://us-housing-regression-data/processed/feature_engineered_holdout.csv
# ⬆️ Uploading /local/vol00/home/troy3/vscode_workspace/Regression_MLOps_End2End/data/processed/cleaning_holdout.csv → s3://us-housing-regression-data/processed/cleaning_holdout.csv
# ⬆️ Uploading /local/vol00/home/troy3/vscode_workspace/Regression_MLOps_End2End/data/processed/feature_engineered_train.csv → s3://us-housing-regression-data/processed/feature_engineered_train.csv
# ⬆️ Uploading /local/vol00/home/troy3/vscode_workspace/Regression_MLOps_End2End/models/xgb_best_model.pkl → s3://us-housing-regression-data/models/xgb_best_model.pkl
